# %% [markdown]
# # Rozšíření Pythonu v C (C Extensions)
#
# Tato lekce vyžaduje kompilaci. V Jupyter Notebooku to může být složitější, proto budeme využívat příkazy terminálu.
#
# ## 1. Příprava C kódu
# Zobrazíme si obsah souboru [`fastprime.c`](./fastprime.c), který obsahuje naši rychlou funkci v C.

# %% [markdown]
# ## 2. Kompilace modulu
# Abychom mohli modul použít, musíme ho zkompilovat. Použijeme k tomu `setup.py`.
#
# **Pozor:** Tento krok vyžaduje, aby byl v systému nainstalován kompilátor (GCC/Clang) a vývojářské hlavičky Pythonu (`python3-dev`). V našem DevContaineru by to mělo být připraveno.

# %%
# Spustíme kompilaci
# !python3 setup.py build_ext --inplace
# Out:
# running build_ext
# building 'fastprime' extension
# x86_64-linux-gnu-gcc -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/include/python3.11 -c fastprime.c -o build/temp.linux-x86_64-cpython-311/fastprime.o
# x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-311/fastprime.o -L/usr/lib/x86_64-linux-gnu -o build/lib.linux-x86_64-cpython-311/fastprime.cpython-311-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-cpython-311/fastprime.cpython-311-x86_64-linux-gnu.so ->

# %% [markdown]
# ## 3. Testování výkonu
# Pokud kompilace proběhla úspěšně (vytvořil se `.so` nebo `.pyd` soubor), můžeme spustit srovnávací skript `main.py`.

# %%
# Spuštění benchmarku
import sys
import subprocess

# Používáme subprocess pro bezpečné spuštění
result = subprocess.run([sys.executable, "main.py"], capture_output=True, text=True)
print(result.stdout)
if result.stderr:
    print("CHYBY:", result.stderr)
# Out:
# --- Srovnání výkonu (hledáme 10000. prvočíslo) ---
# Python:	 104729 (čas: 0.0763 s)
# C Ext:	 104729 (čas: 0.0046 s)
# ----------------------------------------
# C modul je přibližně 16.4x rychlejší!
